# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
# import as pd to save time on typing

import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
# dataframe/dr/variabe= chipo

chipo =  pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = "\t")
chipo # chipo is the dataframe, pd reading data from csvs
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
# need to replace '$' as float instead of integer so that the cent value would remain as cents
# use chipo['item_price'] = chipo['item_price'].str.replace('[\$\,]', '', regex=True).astype(float)

# %%
chipo =  pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = "\t")
chipo['item_price'] = chipo['item_price'].str.replace('[\$\,]', '', regex=True).astype(float)
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# drop duplicates in item_name and quantity, transform data 
# newdf = df1.drop_duplicates(  subset = ['order_id', 'customer_id'],  keep = 'last').reset_index(drop = True)
chipo = chipo.drop_duplicates(subset = ['item_name', 'quantity'],   keep = 'last').reset_index(drop = True)
chipo
# Out:
#      order_id  quantity            item_name  \
# 0         193         3                 Bowl
# 1         212         2        Carnitas Bowl
# 2         217         1         Crispy Tacos
# 3         253         2     Steak Salad Bowl
# 4         279         1                 Bowl
# ..        ...       ...                  ...
# 98       1831         1        Bottled Water
# 99       1832         1   Chicken Soft Tacos
# 100      1832         1  Chips and Guacamole
# 101      1833         1        Steak Burrito
# 102      1834         1   Chicken Salad Bowl
#
#                                     choice_description  item_price
# 0    [Braised Carnitas, Pinto Beans, [Sour Cream, C...       22.20
# 1    [Roasted Chili Corn Salsa, [Fajita Vegetables,...       23.50
# 2                [Adobo-Marinated and Grilled Chicken]        7.40
# 3    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       23.78
# 4    [Adobo-Marinated and Grilled Steak, [Sour Crea...        7.40
# ...

# %%
# select only the products with quantity equals to 1
# How many products cost more than $10
# len(df[(df['col1']=='value1') & (df['col2']=='value2')])

len(chipo[(chipo['quantity']==1) & (chipo['item_price']>10.00)])
# Out:
# 7

# %% [markdown]
# ### Step 5. What is the price of each item?
# ##### print a data frame with only two columns item_name and item_price

# %%
price_per_item = chipo[['item_name', 'item_price']]
price_per_item
# Out:
#                item_name  item_price
# 0                   Bowl       22.20
# 1          Carnitas Bowl       23.50
# 2           Crispy Tacos        7.40
# 3       Steak Salad Bowl       23.78
# 4                   Bowl        7.40
# ..                   ...         ...
# 98         Bottled Water        1.50
# 99    Chicken Soft Tacos        8.75
# 100  Chips and Guacamole        4.45
# 101        Steak Burrito       11.75
# 102   Chicken Salad Bowl        8.75
#
# [103 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by = "item_name")
# Out:
#     order_id  quantity              item_name  \
# 80      1803         1      6 Pack Soft Drink
# 29      1360         2      6 Pack Soft Drink
# 91      1825         1          Barbacoa Bowl
# 92      1827         1       Barbacoa Burrito
# 27      1330         1  Barbacoa Crispy Tacos
# ..       ...       ...                    ...
# 12       668         1    Veggie Crispy Tacos
# 55      1635         1           Veggie Salad
# 88      1818         1      Veggie Salad Bowl
# 46      1559         2      Veggie Soft Tacos
# 22      1132         1      Veggie Soft Tacos
#
#                                    choice_description  item_price
# 80                                         [Lemonade]        6.49
# 29                                        [Diet Coke]       12.98
# 91  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...       11.75
# 92                      [Tomatillo Green Chili Salsa]        9.25
# 27  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...        8.99
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#     order_id  quantity                     item_name choice_description  \
# 32      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#     item_price
# 32       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
# mode function
chipo_salad = chipo[chipo.item_name == "Veggie Salad Bowl"]

len(chipo_salad)
# Out:
# 1

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo_cannedsoda = chipo[chipo.item_name == "Canned Soda"]

len(chipo_cannedsoda)
# Out:
# 3
